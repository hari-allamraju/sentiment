# %%
import spacy

# %%
nlp=spacy.en.English()

# %%
story="""
The story is set in the heartland of Uttar Pradesh who's political landscape is dominated by two politicians Dubey & Jiji. Babu Bihari is a hitman hired by both to get rid of their rivals. He kills for a paltry sum of Rs. 20,000, of which 5000 is the commission to a constable who gets him the hit job. Babu is ferocious & has a very direct approach to hitting his target. He has a reputation of clean hits without any fuss.

Babu leads a very simple life, lives alone in a shanty in a remote location. One fine day Jiji offers him a hit job of a local muscleman. Babu goes survey the routine of his target. There he comes across Fulwa a Cobbler. He is smitten by her beauty & impressed with her head strong attitude. He tries to court her, but his advances are rejected by her. Meanwhile, he kills his target, which is witnessed by Fulwa. In the police investigation, she refuses to identify him. Babu barges into her home & she pokes him instinctively with a sharp tool. Babu somehow manages to control the damage & tells her that he came because he was curious why she did not divulge any information to the police. She tells her that the guy he just killed & his 2 brothers raped her repeatedly. She tells him if he kills rest of the 2 brothers she would spend her entire life with him. Babu promptly kills the 2 remaining brothers.

When he returns for his payment Jiji is furious on him. He has ruined her plan. It was on the insistence of the younger brother, that she got killed the elder brother to forge an alliance with the remaining 2 brothers for upcoming elections. This puts Babu in bad books of Jiji.

Here Babu & Fulwa have a great time & enjoy each other's company. On the other hand, Dubey feels that 3 muscle men (Bahubali) of Jiji are an obstacle to his prospects of winning the election. He gives the contract to kill all 3 Bahubalis to Babu. Babu goes to Jiji & informs her about the contract. He throws an open challenge to her to save her men if she can. He is about to hit his first kill a bullet is already shot missing its target. In ensuing chaos, the victim escapes. It turns out that there is another hitman given the same contract. Babu saves the second hitman from the enraged mob. The second hitman is Bakey, who considers Babu as his guru. Although furious at first that he ruined his kill, Babu makes amends with Bakey. They decide to make this as a game. Of the 3 kills whoever scores higher will win & loser will have to leave the profession.

Babu scores the first kill. He is about to score the second hit, but a cop loyal to Jiji intervenes. In the ensuing scuffle, Babu is hit in the shoulder. He takes him in his police jeep & just about to depart, Bakey sneaks in as a postman & scores the kill. The cop is furious takes him to a jungle to investigate. Babu is rescued by Bakey & takes him to his home. Fulwa removes the bullet from his body & heals him back to health. She is impressed by his sauve looks & strong physique. A chemistry seems to boil amongst the two, which Babu also notices. Babu offers them to spend a night together, shocked at first Fulwa berates him & walks away. Bakey reluctantly backtracks saying that he was going along with their dance & booze filled merriment. Babu was actually testing their integrity & tells Bakey that if he tries getting closer to Fulwa he would kill him.

After recovering from his injury Babu & Bakey collaborate to kill Triloki the last target & closest aide of Jiji. They create a chaos in the rally & abduct him from there in the guise of constables. After killing him they sit near a railway bridge to celebrate their victory. After moments of drunken banter, Bakey reveals that the contract was for 4 people & shoots Babu point blank. Babu falls off the bridge into a cargo train.

Next, we see Babu waking up in a hospital with long hair & beard, apparently from a long coma. He clean-up himself & returns back. His cop friend reveals that after the death of Triloki, Jiji got her entire force to his location, set his house on fire, raped & burnt Fulwa as well. Babu is completely heartbroken & bays for the blood of all the traitors. The first locates Bakey & just as he is about to kill him, Bakey explains that he just executed his contract, principally Babu respect that. He spares his life because Bakey had saved his life in past. Bakey tells him that Dubey revealed his address to Jiji. Thereafter he goes on a killing spree & kills all his nemesis. At the end, the secretary of Dubey (who now owns his empire) gives Babu one more contract. Babu refuses & says that he has left the business. He gives him an address & tells him that he has a strong motive to take this contract.

Babu goes to the address & instinctively avoids a poke from sharp tool, unmistakenly from Fulwa. He is surpirsed to see her alive. Then comes Bakey. It is then revealved that Bakey & Fulwa fell in love the moment they met. Fulwa gives Bakey contract to kill Babu. Babu kills Bakey by tricking him into Russian roulette styled game. He kills Fulwa as well for her betrayal."""

# %%
review=nlp(unicode(story))

# %%
review.ents
# Out:
# (Uttar Pradesh,
#  two,
#  Dubey & Jiji,
#  Babu Bihari,
#  Rs.,
#  20,000,
#  5000,
#  One,
#  Jiji,
#  Fulwa a,
#  Fulwa,
#  2,
#  2,
#  2,
#  Jiji,
#  2,
#  Babu,
#  Jiji,
#  Babu & Fulwa,
#  Dubey,
#  3,
#  Jiji are,
#  3,
#  Jiji &,
#  first,
#  Babu,
#  second,
#  second,
#  Bakey,
#  Babu,
#  first,
#  Babu,
#  Bakey,
#  3,
#  first,
#  second,
#  Jiji,
#  Babu,
#  Bakey,
#  Bakey &,
#  Fulwa,
#  two,
#  Babu,
#  night,
#  first,
#  Bakey,
#  Babu,
#  Bakey,
#  Fulwa he,
#  Babu & Bakey,
#  Triloki,
#  Jiji,
#  Bakey,
#  4,
#  Babu,
#  Babu,
#  Next,
#  Babu,
#  Triloki,
#  Jiji,
#  Fulwa,
#  first,
#  Bakey &,
#  Bakey,
#  Bakey,
#  Bakey,
#  Dubey,
#  Jiji,
#  the end,
#  Dubey,
#  Babu one,
#  Fulwa,
#  Bakey,
#  Bakey & Fulwa,
#  Fulwa,
#  Bakey,
#  Babu,
#  Babu,
#  Bakey,
#  Russian,
#  Fulwa)

# %%
review.sentiment
# Out:
# 0.0

# %%
review.print_tree()
# Out:
# [{u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBN',
#   u'arc': u'ROOT',
#   u'lemma': u'set',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'nsubjpass',
#     u'lemma': u'story',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'DET',
#       u'POS_fine': u'DT',
#       u'arc': u'det',
#       u'lemma': u'the',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'SPACE',
#         u'POS_fine': u'SP',
#         u'arc': u'',
#         u'lemma': u'\n',
#         u'modifiers': [],
#         u'word': u'\n'}],
#       u'word': u'The'}],
#     u'word': u'story'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'auxpass',
#     u'lemma': u'be',
#     u'modifiers': [],
#     u'word': u'is'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'prep',
#     u'lemma': u'in',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'pobj',
#       u'lemma': u'heartland',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'the',
#         u'modifiers': [],
#         u'word': u'the'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'of',
#         u'modifiers': [{u'NE': u'GPE',
#           u'POS_coarse': u'PROPN',
#           u'POS_fine': u'NNP',
#           u'arc': u'pobj',
#           u'lemma': u'Uttar Pradesh',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'VERB',
#             u'POS_fine': u'VBN',
#             u'arc': u'relcl',
#             u'lemma': u'dominate',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'NOUN',
#               u'POS_fine': u'WP',
#               u'arc': u'nsubjpass',
#               u'lemma': u'who',
#               u'modifiers': [],
#               u'word': u'who'},
#              {u'NE': u'',
#               u'POS_coarse': u'NOUN',
#               u'POS_fine': u'NN',
#               u'arc': u'nsubjpass',
#               u'lemma': u'landscape',
#               u'modifiers': [{u'NE': u'',
#                 u'POS_coarse': u'VERB',
#                 u'POS_fine': u'VBZ',
#                 u'arc': u'nmod',
#                 u'lemma': u'be',
#                 u'modifiers': [],
#                 u'word': u"'s"},
#                {u'NE': u'',
#                 u'POS_coarse': u'ADJ',
#                 u'POS_fine': u'JJ',
#                 u'arc': u'amod',
#                 u'lemma': u'political',
#                 u'modifiers': [],
#                 u'word': u'political'}],
#               u'word': u'landscape'},
#              {u'NE': u'',
#               u'POS_coarse': u'VERB',
#               u'POS_fine': u'VBZ',
#               u'arc': u'auxpass',
#               u'lemma': u'be',
#               u'modifiers': [],
#               u'word': u'is'},
#              {u'NE': u'',
#               u'POS_coarse': u'ADP',
#               u'POS_fine': u'IN',
#               u'arc': u'agent',
#               u'lemma': u'by',
#               u'modifiers': [{u'NE': u'',
#                 u'POS_coarse': u'NOUN',
#                 u'POS_fine': u'NNS',
#                 u'arc': u'pobj',
#                 u'lemma': u'politician',
#                 u'modifiers': [{u'NE': u'CARDINAL',
#                   u'POS_coarse': u'NUM',
#                   u'POS_fine': u'CD',
#                   u'arc': u'nummod',
#                   u'lemma': u'two',
#                   u'modifiers': [],
#                   u'word': u'two'},
#                  {u'NE': u'ORG',
#                   u'POS_coarse': u'PROPN',
#                   u'POS_fine': u'NNP',
#                   u'arc': u'appos',
#                   u'lemma': u'Dubey & Jiji',
#                   u'modifiers': [],
#                   u'word': u'Dubey & Jiji'}],
#                 u'word': u'politicians'}],
#               u'word': u'by'}],
#             u'word': u'dominated'}],
#           u'word': u'Uttar Pradesh'}],
#         u'word': u'of'}],
#       u'word': u'heartland'}],
#     u'word': u'in'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'set'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'be',
#   u'modifiers': [{u'NE': u'PERSON',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'Babu Bihari',
#     u'modifiers': [],
#     u'word': u'Babu Bihari'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'attr',
#     u'lemma': u'hitman',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'DET',
#       u'POS_fine': u'DT',
#       u'arc': u'det',
#       u'lemma': u'a',
#       u'modifiers': [],
#       u'word': u'a'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBN',
#       u'arc': u'acl',
#       u'lemma': u'hire',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'agent',
#         u'lemma': u'by',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'DET',
#           u'POS_fine': u'DT',
#           u'arc': u'pobj',
#           u'lemma': u'both',
#           u'modifiers': [],
#           u'word': u'both'}],
#         u'word': u'by'}],
#       u'word': u'hired'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBN',
#       u'arc': u'conj',
#       u'lemma': u'rid',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'VERB',
#         u'POS_fine': u'VB',
#         u'arc': u'auxpass',
#         u'lemma': u'get',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'PART',
#           u'POS_fine': u'TO',
#           u'arc': u'aux',
#           u'lemma': u'to',
#           u'modifiers': [],
#           u'word': u'to'}],
#         u'word': u'get'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'of',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NNS',
#           u'arc': u'pobj',
#           u'lemma': u'rival',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'ADJ',
#             u'POS_fine': u'PRP$',
#             u'arc': u'poss',
#             u'lemma': u'-PRON-',
#             u'modifiers': [],
#             u'word': u'their'}],
#           u'word': u'rivals'}],
#         u'word': u'of'}],
#       u'word': u'rid'}],
#     u'word': u'hitman'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'is'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'kill',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'He'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'prep',
#     u'lemma': u'for',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'pobj',
#       u'lemma': u'sum',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'a',
#         u'modifiers': [],
#         u'word': u'a'},
#        {u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'compound',
#         u'lemma': u'paltry',
#         u'modifiers': [],
#         u'word': u'paltry'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'of',
#         u'modifiers': [{u'NE': u'CARDINAL',
#           u'POS_coarse': u'PROPN',
#           u'POS_fine': u'NNP',
#           u'arc': u'pobj',
#           u'lemma': u'Rs .',
#           u'modifiers': [],
#           u'word': u'Rs .'}],
#         u'word': u'of'}],
#       u'word': u'sum'}],
#     u'word': u'for'}],
#   u'word': u'kills'},
#  {u'NE': u'CARDINAL',
#   u'POS_coarse': u'NUM',
#   u'POS_fine': u'CD',
#   u'arc': u'ROOT',
#   u'lemma': u'20,000',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u',',
#     u'arc': u'punct',
#     u'lemma': u',',
#     u'modifiers': [],
#     u'word': u','},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'conj',
#     u'lemma': u'be',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep||nsubj',
#       u'lemma': u'of',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'WDT',
#         u'arc': u'pobj',
#         u'lemma': u'which',
#         u'modifiers': [],
#         u'word': u'which'}],
#       u'word': u'of'},
#      {u'NE': u'CARDINAL',
#       u'POS_coarse': u'NUM',
#       u'POS_fine': u'CD',
#       u'arc': u'nsubj',
#       u'lemma': u'5000',
#       u'modifiers': [],
#       u'word': u'5000'},
#      {u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'attr',
#       u'lemma': u'commission',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'the',
#         u'modifiers': [],
#         u'word': u'the'}],
#       u'word': u'commission'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'to',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'pobj',
#         u'lemma': u'constable',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'DET',
#           u'POS_fine': u'DT',
#           u'arc': u'det',
#           u'lemma': u'a',
#           u'modifiers': [],
#           u'word': u'a'},
#          {u'NE': u'',
#           u'POS_coarse': u'VERB',
#           u'POS_fine': u'VBZ',
#           u'arc': u'relcl',
#           u'lemma': u'get',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'WP',
#             u'arc': u'nsubj',
#             u'lemma': u'who',
#             u'modifiers': [],
#             u'word': u'who'},
#            {u'NE': u'',
#             u'POS_coarse': u'PRON',
#             u'POS_fine': u'PRP',
#             u'arc': u'dobj',
#             u'lemma': u'-PRON-',
#             u'modifiers': [],
#             u'word': u'him'},
#            {u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'NN',
#             u'arc': u'dobj',
#             u'lemma': u'job',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'DET',
#               u'POS_fine': u'DT',
#               u'arc': u'det',
#               u'lemma': u'the',
#               u'modifiers': [],
#               u'word': u'the'},
#              {u'NE': u'',
#               u'POS_coarse': u'NOUN',
#               u'POS_fine': u'NN',
#               u'arc': u'compound',
#               u'lemma': u'hit',
#               u'modifiers': [],
#               u'word': u'hit'}],
#             u'word': u'job'}],
#           u'word': u'gets'}],
#         u'word': u'constable'}],
#       u'word': u'to'}],
#     u'word': u'is'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'20,000'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'be',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'babu',
#     u'modifiers': [],
#     u'word': u'Babu'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADJ',
#     u'POS_fine': u'JJ',
#     u'arc': u'acomp',
#     u'lemma': u'ferocious',
#     u'modifiers': [],
#     u'word': u'ferocious'},
#    {u'NE': u'',
#     u'POS_coarse': u'CCONJ',
#     u'POS_fine': u'CC',
#     u'arc': u'cc',
#     u'lemma': u'&',
#     u'modifiers': [],
#     u'word': u'&'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'conj',
#     u'lemma': u'have',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'dobj',
#       u'lemma': u'approach',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'a',
#         u'modifiers': [],
#         u'word': u'a'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'JJ',
#         u'arc': u'amod',
#         u'lemma': u'direct',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADV',
#           u'POS_fine': u'RB',
#           u'arc': u'advmod',
#           u'lemma': u'very',
#           u'modifiers': [],
#           u'word': u'very'}],
#         u'word': u'direct'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'to',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'VERB',
#           u'POS_fine': u'VBG',
#           u'arc': u'pcomp',
#           u'lemma': u'hit',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'NN',
#             u'arc': u'dobj',
#             u'lemma': u'target',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'ADJ',
#               u'POS_fine': u'PRP$',
#               u'arc': u'poss',
#               u'lemma': u'-PRON-',
#               u'modifiers': [],
#               u'word': u'his'}],
#             u'word': u'target'}],
#           u'word': u'hitting'}],
#         u'word': u'to'}],
#       u'word': u'approach'}],
#     u'word': u'has'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'is'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'have',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'He'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'dobj',
#     u'lemma': u'reputation',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'DET',
#       u'POS_fine': u'DT',
#       u'arc': u'det',
#       u'lemma': u'a',
#       u'modifiers': [],
#       u'word': u'a'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'of',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NNS',
#         u'arc': u'pobj',
#         u'lemma': u'hit',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADJ',
#           u'POS_fine': u'JJ',
#           u'arc': u'amod',
#           u'lemma': u'clean',
#           u'modifiers': [],
#           u'word': u'clean'},
#          {u'NE': u'',
#           u'POS_coarse': u'ADP',
#           u'POS_fine': u'IN',
#           u'arc': u'prep',
#           u'lemma': u'without',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'NN',
#             u'arc': u'pobj',
#             u'lemma': u'fuss',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'DET',
#               u'POS_fine': u'DT',
#               u'arc': u'det',
#               u'lemma': u'any',
#               u'modifiers': [],
#               u'word': u'any'}],
#             u'word': u'fuss'}],
#           u'word': u'without'}],
#         u'word': u'hits'}],
#       u'word': u'of'}],
#     u'word': u'reputation'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'SPACE',
#       u'POS_fine': u'SP',
#       u'arc': u'',
#       u'lemma': u'\n\n',
#       u'modifiers': [],
#       u'word': u'\n\n'}],
#     u'word': u'.'}],
#   u'word': u'has'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'lead',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'babu',
#     u'modifiers': [],
#     u'word': u'Babu'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'ccomp',
#     u'lemma': u'live',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'nsubj',
#       u'lemma': u'life',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'a',
#         u'modifiers': [],
#         u'word': u'a'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'JJ',
#         u'arc': u'amod',
#         u'lemma': u'simple',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADV',
#           u'POS_fine': u'RB',
#           u'arc': u'advmod',
#           u'lemma': u'very',
#           u'modifiers': [],
#           u'word': u'very'}],
#         u'word': u'simple'},
#        {u'NE': u'',
#         u'POS_coarse': u'PUNCT',
#         u'POS_fine': u',',
#         u'arc': u'punct',
#         u'lemma': u',',
#         u'modifiers': [],
#         u'word': u','}],
#       u'word': u'life'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADV',
#       u'POS_fine': u'RB',
#       u'arc': u'advmod',
#       u'lemma': u'alone',
#       u'modifiers': [],
#       u'word': u'alone'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'in',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'pobj',
#         u'lemma': u'shanty',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'DET',
#           u'POS_fine': u'DT',
#           u'arc': u'det',
#           u'lemma': u'a',
#           u'modifiers': [],
#           u'word': u'a'},
#          {u'NE': u'',
#           u'POS_coarse': u'ADP',
#           u'POS_fine': u'IN',
#           u'arc': u'prep',
#           u'lemma': u'in',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'NN',
#             u'arc': u'pobj',
#             u'lemma': u'location',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'DET',
#               u'POS_fine': u'DT',
#               u'arc': u'det',
#               u'lemma': u'a',
#               u'modifiers': [],
#               u'word': u'a'},
#              {u'NE': u'',
#               u'POS_coarse': u'ADJ',
#               u'POS_fine': u'JJ',
#               u'arc': u'amod',
#               u'lemma': u'remote',
#               u'modifiers': [],
#               u'word': u'remote'}],
#             u'word': u'location'}],
#           u'word': u'in'}],
#         u'word': u'shanty'}],
#       u'word': u'in'}],
#     u'word': u'lives'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'leads'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'offer',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'npadvmod',
#     u'lemma': u'day',
#     u'modifiers': [{u'NE': u'CARDINAL',
#       u'POS_coarse': u'NUM',
#       u'POS_fine': u'CD',
#       u'arc': u'nummod',
#       u'lemma': u'One',
#       u'modifiers': [],
#       u'word': u'One'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADJ',
#       u'POS_fine': u'JJ',
#       u'arc': u'amod',
#       u'lemma': u'fine',
#       u'modifiers': [],
#       u'word': u'fine'}],
#     u'word': u'day'},
#    {u'NE': u'PERSON',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'Jiji',
#     u'modifiers': [],
#     u'word': u'Jiji'},
#    {u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'dobj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'him'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'dobj',
#     u'lemma': u'job',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'DET',
#       u'POS_fine': u'DT',
#       u'arc': u'det',
#       u'lemma': u'a',
#       u'modifiers': [],
#       u'word': u'a'},
#      {u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'amod',
#       u'lemma': u'hit',
#       u'modifiers': [],
#       u'word': u'hit'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'of',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'pobj',
#         u'lemma': u'muscleman',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'DET',
#           u'POS_fine': u'DT',
#           u'arc': u'det',
#           u'lemma': u'a',
#           u'modifiers': [],
#           u'word': u'a'},
#          {u'NE': u'',
#           u'POS_coarse': u'ADJ',
#           u'POS_fine': u'JJ',
#           u'arc': u'amod',
#           u'lemma': u'local',
#           u'modifiers': [],
#           u'word': u'local'}],
#         u'word': u'muscleman'}],
#       u'word': u'of'}],
#     u'word': u'job'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'offers'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'go',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'nsubj',
#     u'lemma': u'babu',
#     u'modifiers': [],
#     u'word': u'Babu'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VB',
#     u'arc': u'advcl',
#     u'lemma': u'survey',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'dobj',
#       u'lemma': u'routine',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'the',
#         u'modifiers': [],
#         u'word': u'the'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'of',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NN',
#           u'arc': u'pobj',
#           u'lemma': u'target',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'ADJ',
#             u'POS_fine': u'PRP$',
#             u'arc': u'poss',
#             u'lemma': u'-PRON-',
#             u'modifiers': [],
#             u'word': u'his'}],
#           u'word': u'target'}],
#         u'word': u'of'}],
#       u'word': u'routine'}],
#     u'word': u'survey'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'goes'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'come',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'ADV',
#     u'POS_fine': u'RB',
#     u'arc': u'advmod',
#     u'lemma': u'there',
#     u'modifiers': [],
#     u'word': u'There'},
#    {u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'he'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'prep',
#     u'lemma': u'across',
#     u'modifiers': [{u'NE': u'ORG',
#       u'POS_coarse': u'PROPN',
#       u'POS_fine': u'NNP',
#       u'arc': u'pobj',
#       u'lemma': u'Fulwa a',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'PROPN',
#         u'POS_fine': u'NNP',
#         u'arc': u'appos',
#         u'lemma': u'cobbler',
#         u'modifiers': [],
#         u'word': u'Cobbler'}],
#       u'word': u'Fulwa a'}],
#     u'word': u'across'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'comes'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBN',
#   u'arc': u'ROOT',
#   u'lemma': u'smite',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubjpass',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'He'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'auxpass',
#     u'lemma': u'be',
#     u'modifiers': [],
#     u'word': u'is'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'agent',
#     u'lemma': u'by',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'pobj',
#       u'lemma': u'beauty',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'PRP$',
#         u'arc': u'poss',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'her'},
#        {u'NE': u'',
#         u'POS_coarse': u'CCONJ',
#         u'POS_fine': u'CC',
#         u'arc': u'cc',
#         u'lemma': u'&',
#         u'modifiers': [],
#         u'word': u'&'}],
#       u'word': u'beauty'}],
#     u'word': u'by'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADJ',
#     u'POS_fine': u'JJ',
#     u'arc': u'advcl',
#     u'lemma': u'impressed',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'with',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'pobj',
#         u'lemma': u'attitude',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADJ',
#           u'POS_fine': u'PRP$',
#           u'arc': u'poss',
#           u'lemma': u'-PRON-',
#           u'modifiers': [],
#           u'word': u'her'},
#          {u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NN',
#           u'arc': u'amod',
#           u'lemma': u'head',
#           u'modifiers': [],
#           u'word': u'head'},
#          {u'NE': u'',
#           u'POS_coarse': u'ADJ',
#           u'POS_fine': u'JJ',
#           u'arc': u'amod',
#           u'lemma': u'strong',
#           u'modifiers': [],
#           u'word': u'strong'}],
#         u'word': u'attitude'}],
#       u'word': u'with'}],
#     u'word': u'impressed'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'smitten'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'try',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'He'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VB',
#     u'arc': u'xcomp',
#     u'lemma': u'court',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'PART',
#       u'POS_fine': u'TO',
#       u'arc': u'aux',
#       u'lemma': u'to',
#       u'modifiers': [],
#       u'word': u'to'},
#      {u'NE': u'',
#       u'POS_coarse': u'PRON',
#       u'POS_fine': u'PRP',
#       u'arc': u'dobj',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'her'}],
#     u'word': u'court'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u',',
#     u'arc': u'punct',
#     u'lemma': u',',
#     u'modifiers': [],
#     u'word': u','},
#    {u'NE': u'',
#     u'POS_coarse': u'CCONJ',
#     u'POS_fine': u'CC',
#     u'arc': u'cc',
#     u'lemma': u'but',
#     u'modifiers': [],
#     u'word': u'but'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBN',
#     u'arc': u'conj',
#     u'lemma': u'reject',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NNS',
#       u'arc': u'nsubjpass',
#       u'lemma': u'advance',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'PRP$',
#         u'arc': u'poss',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'his'}],
#       u'word': u'advances'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBP',
#       u'arc': u'auxpass',
#       u'lemma': u'be',
#       u'modifiers': [],
#       u'word': u'are'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'agent',
#       u'lemma': u'by',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'PRON',
#         u'POS_fine': u'PRP',
#         u'arc': u'pobj',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'her'}],
#       u'word': u'by'}],
#     u'word': u'rejected'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'tries'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'kill',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'ADV',
#     u'POS_fine': u'RB',
#     u'arc': u'advmod',
#     u'lemma': u'meanwhile',
#     u'modifiers': [],
#     u'word': u'Meanwhile'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u',',
#     u'arc': u'punct',
#     u'lemma': u',',
#     u'modifiers': [],
#     u'word': u','},
#    {u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'he'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'dobj',
#     u'lemma': u'target',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADJ',
#       u'POS_fine': u'PRP$',
#       u'arc': u'poss',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'his'},
#      {u'NE': u'',
#       u'POS_coarse': u'PUNCT',
#       u'POS_fine': u',',
#       u'arc': u'punct',
#       u'lemma': u',',
#       u'modifiers': [],
#       u'word': u','}],
#     u'word': u'target'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBN',
#     u'arc': u'advcl',
#     u'lemma': u'witness',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADJ',
#       u'POS_fine': u'WDT',
#       u'arc': u'nsubjpass',
#       u'lemma': u'which',
#       u'modifiers': [],
#       u'word': u'which'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBZ',
#       u'arc': u'auxpass',
#       u'lemma': u'be',
#       u'modifiers': [],
#       u'word': u'is'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'agent',
#       u'lemma': u'by',
#       u'modifiers': [{u'NE': u'ORG',
#         u'POS_coarse': u'PROPN',
#         u'POS_fine': u'NNP',
#         u'arc': u'pobj',
#         u'lemma': u'Fulwa',
#         u'modifiers': [],
#         u'word': u'Fulwa'}],
#       u'word': u'by'}],
#     u'word': u'witnessed'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'kills'},
#  {u'NE': u'',
#   u'POS_coarse': u'ADJ',
#   u'POS_fine': u'JJ',
#   u'arc': u'ROOT',
#   u'lemma': u'babu',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'meta',
#     u'lemma': u'refuse',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'in',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'pobj',
#         u'lemma': u'investigation',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'DET',
#           u'POS_fine': u'DT',
#           u'arc': u'det',
#           u'lemma': u'the',
#           u'modifiers': [],
#           u'word': u'the'},
#          {u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NN',
#           u'arc': u'compound',
#           u'lemma': u'police',
#           u'modifiers': [],
#           u'word': u'police'}],
#         u'word': u'investigation'}],
#       u'word': u'In'},
#      {u'NE': u'',
#       u'POS_coarse': u'PUNCT',
#       u'POS_fine': u',',
#       u'arc': u'punct',
#       u'lemma': u',',
#       u'modifiers': [],
#       u'word': u','},
#      {u'NE': u'',
#       u'POS_coarse': u'PRON',
#       u'POS_fine': u'PRP',
#       u'arc': u'nsubj',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'she'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VB',
#       u'arc': u'xcomp',
#       u'lemma': u'identify',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'PART',
#         u'POS_fine': u'TO',
#         u'arc': u'aux',
#         u'lemma': u'to',
#         u'modifiers': [],
#         u'word': u'to'},
#        {u'NE': u'',
#         u'POS_coarse': u'PRON',
#         u'POS_fine': u'PRP',
#         u'arc': u'dobj',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'him'}],
#       u'word': u'identify'},
#      {u'NE': u'',
#       u'POS_coarse': u'PUNCT',
#       u'POS_fine': u'.',
#       u'arc': u'punct',
#       u'lemma': u'.',
#       u'modifiers': [],
#       u'word': u'.'}],
#     u'word': u'refuses'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NNS',
#     u'arc': u'dobj',
#     u'lemma': u'barge',
#     u'modifiers': [],
#     u'word': u'barges'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'prep',
#     u'lemma': u'into',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'pobj',
#       u'lemma': u'home',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'PRP$',
#         u'arc': u'poss',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'her'}],
#       u'word': u'home'}],
#     u'word': u'into'},
#    {u'NE': u'',
#     u'POS_coarse': u'CCONJ',
#     u'POS_fine': u'CC',
#     u'arc': u'cc',
#     u'lemma': u'&',
#     u'modifiers': [],
#     u'word': u'&'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'conj',
#     u'lemma': u'poke',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'PRON',
#       u'POS_fine': u'PRP',
#       u'arc': u'nsubj',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'she'},
#      {u'NE': u'',
#       u'POS_coarse': u'PRON',
#       u'POS_fine': u'PRP',
#       u'arc': u'dobj',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'him'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADV',
#       u'POS_fine': u'RB',
#       u'arc': u'advmod',
#       u'lemma': u'instinctively',
#       u'modifiers': [],
#       u'word': u'instinctively'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'with',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'pobj',
#         u'lemma': u'tool',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'DET',
#           u'POS_fine': u'DT',
#           u'arc': u'det',
#           u'lemma': u'a',
#           u'modifiers': [],
#           u'word': u'a'},
#          {u'NE': u'',
#           u'POS_coarse': u'ADJ',
#           u'POS_fine': u'JJ',
#           u'arc': u'amod',
#           u'lemma': u'sharp',
#           u'modifiers': [],
#           u'word': u'sharp'}],
#         u'word': u'tool'}],
#       u'word': u'with'}],
#     u'word': u'pokes'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'Babu'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'manage',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'babu',
#     u'modifiers': [],
#     u'word': u'Babu'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADV',
#     u'POS_fine': u'RB',
#     u'arc': u'advmod',
#     u'lemma': u'somehow',
#     u'modifiers': [],
#     u'word': u'somehow'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VB',
#     u'arc': u'xcomp',
#     u'lemma': u'control',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'PART',
#       u'POS_fine': u'TO',
#       u'arc': u'aux',
#       u'lemma': u'to',
#       u'modifiers': [],
#       u'word': u'to'}],
#     u'word': u'control'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'advcl',
#     u'lemma': u'tell',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'nsubj',
#       u'lemma': u'damage',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'the',
#         u'modifiers': [],
#         u'word': u'the'},
#        {u'NE': u'',
#         u'POS_coarse': u'CCONJ',
#         u'POS_fine': u'CC',
#         u'arc': u'cc',
#         u'lemma': u'&',
#         u'modifiers': [],
#         u'word': u'&'}],
#       u'word': u'damage'},
#      {u'NE': u'',
#       u'POS_coarse': u'PRON',
#       u'POS_fine': u'PRP',
#       u'arc': u'dobj',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'her'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBD',
#       u'arc': u'ccomp',
#       u'lemma': u'come',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'mark',
#         u'lemma': u'that',
#         u'modifiers': [],
#         u'word': u'that'},
#        {u'NE': u'',
#         u'POS_coarse': u'PRON',
#         u'POS_fine': u'PRP',
#         u'arc': u'nsubj',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'he'},
#        {u'NE': u'',
#         u'POS_coarse': u'VERB',
#         u'POS_fine': u'VBD',
#         u'arc': u'advcl',
#         u'lemma': u'be',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADP',
#           u'POS_fine': u'IN',
#           u'arc': u'mark',
#           u'lemma': u'because',
#           u'modifiers': [],
#           u'word': u'because'},
#          {u'NE': u'',
#           u'POS_coarse': u'PRON',
#           u'POS_fine': u'PRP',
#           u'arc': u'nsubj',
#           u'lemma': u'-PRON-',
#           u'modifiers': [],
#           u'word': u'he'},
#          {u'NE': u'',
#           u'POS_coarse': u'ADJ',
#           u'POS_fine': u'JJ',
#           u'arc': u'acomp',
#           u'lemma': u'curious',
#           u'modifiers': [],
#           u'word': u'curious'},
#          {u'NE': u'',
#           u'POS_coarse': u'VERB',
#           u'POS_fine': u'VB',
#           u'arc': u'ccomp',
#           u'lemma': u'divulge',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'ADV',
#             u'POS_fine': u'WRB',
#             u'arc': u'advmod',
#             u'lemma': u'why',
#             u'modifiers': [],
#             u'word': u'why'},
#            {u'NE': u'',
#             u'POS_coarse': u'PRON',
#             u'POS_fine': u'PRP',
#             u'arc': u'nsubj',
#             u'lemma': u'-PRON-',
#             u'modifiers': [],
#             u'word': u'she'},
#            {u'NE': u'',
#             u'POS_coarse': u'VERB',
#             u'POS_fine': u'VBD',
#             u'arc': u'aux',
#             u'lemma': u'do',
#             u'modifiers': [],
#             u'word': u'did'},
#            {u'NE': u'',
#             u'POS_coarse': u'ADV',
#             u'POS_fine': u'RB',
#             u'arc': u'neg',
#             u'lemma': u'not',
#             u'modifiers': [],
#             u'word': u'not'},
#            {u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'NN',
#             u'arc': u'dobj',
#             u'lemma': u'information',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'DET',
#               u'POS_fine': u'DT',
#               u'arc': u'det',
#               u'lemma': u'any',
#               u'modifiers': [],
#               u'word': u'any'},
#              {u'NE': u'',
#               u'POS_coarse': u'ADP',
#               u'POS_fine': u'IN',
#               u'arc': u'prep',
#               u'lemma': u'to',
#               u'modifiers': [{u'NE': u'',
#                 u'POS_coarse': u'NOUN',
#                 u'POS_fine': u'NN',
#                 u'arc': u'pobj',
#                 u'lemma': u'police',
#                 u'modifiers': [{u'NE': u'',
#                   u'POS_coarse': u'DET',
#                   u'POS_fine': u'DT',
#                   u'arc': u'det',
#                   u'lemma': u'the',
#                   u'modifiers': [],
#                   u'word': u'the'}],
#                 u'word': u'police'}],
#               u'word': u'to'}],
#             u'word': u'information'}],
#           u'word': u'divulge'}],
#         u'word': u'was'}],
#       u'word': u'came'}],
#     u'word': u'tells'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'manages'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'tell',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'She'},
#    {u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'dobj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'her'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'dobj',
#     u'lemma': u'that',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'pobj',
#       u'lemma': u'guy',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'the',
#         u'modifiers': [],
#         u'word': u'the'},
#        {u'NE': u'',
#         u'POS_coarse': u'VERB',
#         u'POS_fine': u'VBD',
#         u'arc': u'relcl',
#         u'lemma': u'kill',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'PRON',
#           u'POS_fine': u'PRP',
#           u'arc': u'nsubj',
#           u'lemma': u'-PRON-',
#           u'modifiers': [],
#           u'word': u'he'},
#          {u'NE': u'',
#           u'POS_coarse': u'ADV',
#           u'POS_fine': u'RB',
#           u'arc': u'advmod',
#           u'lemma': u'just',
#           u'modifiers': [],
#           u'word': u'just'},
#          {u'NE': u'',
#           u'POS_coarse': u'CCONJ',
#           u'POS_fine': u'CC',
#           u'arc': u'cc',
#           u'lemma': u'&',
#           u'modifiers': [],
#           u'word': u'&'},
#          {u'NE': u'',
#           u'POS_coarse': u'VERB',
#           u'POS_fine': u'VBD',
#           u'arc': u'conj',
#           u'lemma': u'rap',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'NNS',
#             u'arc': u'nsubj',
#             u'lemma': u'brother',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'ADJ',
#               u'POS_fine': u'PRP$',
#               u'arc': u'poss',
#               u'lemma': u'-PRON-',
#               u'modifiers': [],
#               u'word': u'his'},
#              {u'NE': u'CARDINAL',
#               u'POS_coarse': u'NUM',
#               u'POS_fine': u'CD',
#               u'arc': u'nummod',
#               u'lemma': u'2',
#               u'modifiers': [],
#               u'word': u'2'}],
#             u'word': u'brothers'},
#            {u'NE': u'',
#             u'POS_coarse': u'PRON',
#             u'POS_fine': u'PRP',
#             u'arc': u'dobj',
#             u'lemma': u'-PRON-',
#             u'modifiers': [],
#             u'word': u'her'},
#            {u'NE': u'',
#             u'POS_coarse': u'ADV',
#             u'POS_fine': u'RB',
#             u'arc': u'advmod',
#             u'lemma': u'repeatedly',
#             u'modifiers': [],
#             u'word': u'repeatedly'},
#            {u'NE': u'',
#             u'POS_coarse': u'PUNCT',
#             u'POS_fine': u'.',
#             u'arc': u'punct',
#             u'lemma': u'.',
#             u'modifiers': [],
#             u'word': u'.'}],
#           u'word': u'raped'}],
#         u'word': u'killed'}],
#       u'word': u'guy'}],
#     u'word': u'that'}],
#   u'word': u'tells'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'tell',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'She'},
#    {u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'dobj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'him'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VB',
#     u'arc': u'ccomp',
#     u'lemma': u'spend',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBZ',
#       u'arc': u'advcl',
#       u'lemma': u'kill',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'mark',
#         u'lemma': u'if',
#         u'modifiers': [],
#         u'word': u'if'},
#        {u'NE': u'',
#         u'POS_coarse': u'PRON',
#         u'POS_fine': u'PRP',
#         u'arc': u'nsubj',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'he'},
#        {u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'dobj',
#         u'lemma': u'rest',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADP',
#           u'POS_fine': u'IN',
#           u'arc': u'prep',
#           u'lemma': u'of',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'NOUN',
#             u'POS_fine': u'NNS',
#             u'arc': u'pobj',
#             u'lemma': u'brother',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'DET',
#               u'POS_fine': u'DT',
#               u'arc': u'det',
#               u'lemma': u'the',
#               u'modifiers': [],
#               u'word': u'the'},
#              {u'NE': u'CARDINAL',
#               u'POS_coarse': u'NUM',
#               u'POS_fine': u'CD',
#               u'arc': u'nummod',
#               u'lemma': u'2',
#               u'modifiers': [],
#               u'word': u'2'}],
#             u'word': u'brothers'}],
#           u'word': u'of'}],
#         u'word': u'rest'}],
#       u'word': u'kills'},
#      {u'NE': u'',
#       u'POS_coarse': u'PRON',
#       u'POS_fine': u'PRP',
#       u'arc': u'nsubj',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'she'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'MD',
#       u'arc': u'aux',
#       u'lemma': u'would',
#       u'modifiers': [],
#       u'word': u'would'},
#      {u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'dobj',
#       u'lemma': u'life',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'PRP$',
#         u'arc': u'poss',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'her'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADJ',
#         u'POS_fine': u'JJ',
#         u'arc': u'amod',
#         u'lemma': u'entire',
#         u'modifiers': [],
#         u'word': u'entire'}],
#       u'word': u'life'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'with',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'PRON',
#         u'POS_fine': u'PRP',
#         u'arc': u'pobj',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'him'}],
#       u'word': u'with'}],
#     u'word': u'spend'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'tells'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'kill',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'babu',
#     u'modifiers': [],
#     u'word': u'Babu'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADV',
#     u'POS_fine': u'RB',
#     u'arc': u'advmod',
#     u'lemma': u'promptly',
#     u'modifiers': [],
#     u'word': u'promptly'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NNS',
#     u'arc': u'dobj',
#     u'lemma': u'brother',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'DET',
#       u'POS_fine': u'DT',
#       u'arc': u'det',
#       u'lemma': u'the',
#       u'modifiers': [],
#       u'word': u'the'},
#      {u'NE': u'CARDINAL',
#       u'POS_coarse': u'NUM',
#       u'POS_fine': u'CD',
#       u'arc': u'nummod',
#       u'lemma': u'2',
#       u'modifiers': [],
#       u'word': u'2'},
#      {u'NE': u'',
# ...
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'He'},
#    {u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'dobj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'him'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'npadvmod',
#     u'lemma': u'address',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'DET',
#       u'POS_fine': u'DT',
#       u'arc': u'det',
#       u'lemma': u'an',
#       u'modifiers': [],
#       u'word': u'an'},
#      {u'NE': u'',
#       u'POS_coarse': u'CCONJ',
#       u'POS_fine': u'CC',
#       u'arc': u'cc',
#       u'lemma': u'&',
#       u'modifiers': [],
#       u'word': u'&'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBZ',
#       u'arc': u'conj',
#       u'lemma': u'tell',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'PRON',
#         u'POS_fine': u'PRP',
#         u'arc': u'dobj',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'him'},
#        {u'NE': u'',
#         u'POS_coarse': u'VERB',
#         u'POS_fine': u'VBZ',
#         u'arc': u'ccomp',
#         u'lemma': u'have',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADP',
#           u'POS_fine': u'IN',
#           u'arc': u'mark',
#           u'lemma': u'that',
#           u'modifiers': [],
#           u'word': u'that'},
#          {u'NE': u'',
#           u'POS_coarse': u'PRON',
#           u'POS_fine': u'PRP',
#           u'arc': u'nsubj',
#           u'lemma': u'-PRON-',
#           u'modifiers': [],
#           u'word': u'he'},
#          {u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NN',
#           u'arc': u'dobj',
#           u'lemma': u'motive',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'DET',
#             u'POS_fine': u'DT',
#             u'arc': u'det',
#             u'lemma': u'a',
#             u'modifiers': [],
#             u'word': u'a'},
#            {u'NE': u'',
#             u'POS_coarse': u'ADJ',
#             u'POS_fine': u'JJ',
#             u'arc': u'amod',
#             u'lemma': u'strong',
#             u'modifiers': [],
#             u'word': u'strong'},
#            {u'NE': u'',
#             u'POS_coarse': u'VERB',
#             u'POS_fine': u'VB',
#             u'arc': u'acl',
#             u'lemma': u'take',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'PART',
#               u'POS_fine': u'TO',
#               u'arc': u'aux',
#               u'lemma': u'to',
#               u'modifiers': [],
#               u'word': u'to'},
#              {u'NE': u'',
#               u'POS_coarse': u'NOUN',
#               u'POS_fine': u'NN',
#               u'arc': u'dobj',
#               u'lemma': u'contract',
#               u'modifiers': [{u'NE': u'',
#                 u'POS_coarse': u'DET',
#                 u'POS_fine': u'DT',
#                 u'arc': u'det',
#                 u'lemma': u'this',
#                 u'modifiers': [],
#                 u'word': u'this'}],
#               u'word': u'contract'}],
#             u'word': u'take'}],
#           u'word': u'motive'}],
#         u'word': u'has'}],
#       u'word': u'tells'}],
#     u'word': u'address'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'SPACE',
#       u'POS_fine': u'SP',
#       u'arc': u'',
#       u'lemma': u'\n\n',
#       u'modifiers': [],
#       u'word': u'\n\n'}],
#     u'word': u'.'}],
#   u'word': u'gives'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'go',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'nsubj',
#     u'lemma': u'babu',
#     u'modifiers': [],
#     u'word': u'Babu'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'prep',
#     u'lemma': u'to',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'pobj',
#       u'lemma': u'address',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'the',
#         u'modifiers': [],
#         u'word': u'the'}],
#       u'word': u'address'}],
#     u'word': u'to'},
#    {u'NE': u'',
#     u'POS_coarse': u'CCONJ',
#     u'POS_fine': u'CC',
#     u'arc': u'cc',
#     u'lemma': u'&',
#     u'modifiers': [],
#     u'word': u'&'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'conj',
#     u'lemma': u'avoid',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADV',
#       u'POS_fine': u'RB',
#       u'arc': u'advmod',
#       u'lemma': u'instinctively',
#       u'modifiers': [],
#       u'word': u'instinctively'},
#      {u'NE': u'',
#       u'POS_coarse': u'NOUN',
#       u'POS_fine': u'NN',
#       u'arc': u'dobj',
#       u'lemma': u'poke',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'det',
#         u'lemma': u'a',
#         u'modifiers': [],
#         u'word': u'a'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'from',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NN',
#           u'arc': u'pobj',
#           u'lemma': u'tool',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'ADJ',
#             u'POS_fine': u'JJ',
#             u'arc': u'amod',
#             u'lemma': u'sharp',
#             u'modifiers': [],
#             u'word': u'sharp'},
#            {u'NE': u'',
#             u'POS_coarse': u'PUNCT',
#             u'POS_fine': u',',
#             u'arc': u'punct',
#             u'lemma': u',',
#             u'modifiers': [],
#             u'word': u','}],
#           u'word': u'tool'}],
#         u'word': u'from'}],
#       u'word': u'poke'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADV',
#       u'POS_fine': u'RB',
#       u'arc': u'dobj',
#       u'lemma': u'unmistakenly',
#       u'modifiers': [],
#       u'word': u'unmistakenly'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'from',
#       u'modifiers': [{u'NE': u'GPE',
#         u'POS_coarse': u'PROPN',
#         u'POS_fine': u'NNP',
#         u'arc': u'pobj',
#         u'lemma': u'Fulwa',
#         u'modifiers': [],
#         u'word': u'Fulwa'}],
#       u'word': u'from'}],
#     u'word': u'avoids'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'goes'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBN',
#   u'arc': u'ROOT',
#   u'lemma': u'surpirs',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubjpass',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'He'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBZ',
#     u'arc': u'auxpass',
#     u'lemma': u'be',
#     u'modifiers': [],
#     u'word': u'is'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VB',
#     u'arc': u'xcomp',
#     u'lemma': u'see',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'PART',
#       u'POS_fine': u'TO',
#       u'arc': u'aux',
#       u'lemma': u'to',
#       u'modifiers': [],
#       u'word': u'to'},
#      {u'NE': u'',
#       u'POS_coarse': u'PRON',
#       u'POS_fine': u'PRP',
#       u'arc': u'dobj',
#       u'lemma': u'-PRON-',
#       u'modifiers': [],
#       u'word': u'her'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADJ',
#       u'POS_fine': u'JJ',
#       u'arc': u'oprd',
#       u'lemma': u'alive',
#       u'modifiers': [],
#       u'word': u'alive'}],
#     u'word': u'see'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'surpirsed'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'come',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'ADV',
#     u'POS_fine': u'RB',
#     u'arc': u'advmod',
#     u'lemma': u'then',
#     u'modifiers': [],
#     u'word': u'Then'},
#    {u'NE': u'PERSON',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'Bakey',
#     u'modifiers': [],
#     u'word': u'Bakey'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'comes'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'be',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'It'},
#    {u'NE': u'',
#     u'POS_coarse': u'VERB',
#     u'POS_fine': u'VBN',
#     u'arc': u'dep',
#     u'lemma': u'revealv',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADV',
#       u'POS_fine': u'RB',
#       u'arc': u'advmod',
#       u'lemma': u'then',
#       u'modifiers': [],
#       u'word': u'then'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBD',
#       u'arc': u'ccomp',
#       u'lemma': u'fall',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'DET',
#         u'POS_fine': u'DT',
#         u'arc': u'mark',
#         u'lemma': u'that',
#         u'modifiers': [],
#         u'word': u'that'},
#        {u'NE': u'ORG',
#         u'POS_coarse': u'PROPN',
#         u'POS_fine': u'NNP',
#         u'arc': u'nsubj',
#         u'lemma': u'Bakey & Fulwa',
#         u'modifiers': [],
#         u'word': u'Bakey & Fulwa'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'in',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NN',
#           u'arc': u'pobj',
#           u'lemma': u'love',
#           u'modifiers': [],
#           u'word': u'love'}],
#         u'word': u'in'},
#        {u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'npadvmod',
#         u'lemma': u'moment',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'DET',
#           u'POS_fine': u'DT',
#           u'arc': u'det',
#           u'lemma': u'the',
#           u'modifiers': [],
#           u'word': u'the'},
#          {u'NE': u'',
#           u'POS_coarse': u'VERB',
#           u'POS_fine': u'VBD',
#           u'arc': u'relcl',
#           u'lemma': u'meet',
#           u'modifiers': [{u'NE': u'',
#             u'POS_coarse': u'PRON',
#             u'POS_fine': u'PRP',
#             u'arc': u'nsubj',
#             u'lemma': u'-PRON-',
#             u'modifiers': [],
#             u'word': u'they'}],
#           u'word': u'met'}],
#         u'word': u'moment'}],
#       u'word': u'fell'}],
#     u'word': u'revealved'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'is'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'give',
#   u'modifiers': [{u'NE': u'ORG',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'Fulwa',
#     u'modifiers': [],
#     u'word': u'Fulwa'},
#    {u'NE': u'',
#     u'POS_coarse': u'NOUN',
#     u'POS_fine': u'NN',
#     u'arc': u'dobj',
#     u'lemma': u'contract',
#     u'modifiers': [{u'NE': u'ORG',
#       u'POS_coarse': u'PROPN',
#       u'POS_fine': u'NNP',
#       u'arc': u'compound',
#       u'lemma': u'Bakey',
#       u'modifiers': [],
#       u'word': u'Bakey'},
#      {u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VB',
#       u'arc': u'acl',
#       u'lemma': u'kill',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'PART',
#         u'POS_fine': u'TO',
#         u'arc': u'aux',
#         u'lemma': u'to',
#         u'modifiers': [],
#         u'word': u'to'},
#        {u'NE': u'PERSON',
#         u'POS_coarse': u'PROPN',
#         u'POS_fine': u'NNP',
#         u'arc': u'dobj',
#         u'lemma': u'Babu',
#         u'modifiers': [],
#         u'word': u'Babu'}],
#       u'word': u'kill'}],
#     u'word': u'contract'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'gives'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'kill',
#   u'modifiers': [{u'NE': u'PERSON',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'nsubj',
#     u'lemma': u'Babu',
#     u'modifiers': [],
#     u'word': u'Babu'},
#    {u'NE': u'PERSON',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'dobj',
#     u'lemma': u'Bakey',
#     u'modifiers': [],
#     u'word': u'Bakey'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADP',
#     u'POS_fine': u'IN',
#     u'arc': u'prep',
#     u'lemma': u'by',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'VERB',
#       u'POS_fine': u'VBG',
#       u'arc': u'pcomp',
#       u'lemma': u'trick',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'PRON',
#         u'POS_fine': u'PRP',
#         u'arc': u'dobj',
#         u'lemma': u'-PRON-',
#         u'modifiers': [],
#         u'word': u'him'},
#        {u'NE': u'',
#         u'POS_coarse': u'ADP',
#         u'POS_fine': u'IN',
#         u'arc': u'prep',
#         u'lemma': u'into',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'NOUN',
#           u'POS_fine': u'NN',
#           u'arc': u'pobj',
#           u'lemma': u'roulette',
#           u'modifiers': [{u'NE': u'NORP',
#             u'POS_coarse': u'ADJ',
#             u'POS_fine': u'JJ',
#             u'arc': u'amod',
#             u'lemma': u'Russian',
#             u'modifiers': [],
#             u'word': u'Russian'},
#            {u'NE': u'',
#             u'POS_coarse': u'VERB',
#             u'POS_fine': u'VBN',
#             u'arc': u'acl',
#             u'lemma': u'style',
#             u'modifiers': [{u'NE': u'',
#               u'POS_coarse': u'NOUN',
#               u'POS_fine': u'NN',
#               u'arc': u'dobj',
#               u'lemma': u'game',
#               u'modifiers': [],
#               u'word': u'game'}],
#             u'word': u'styled'}],
#           u'word': u'roulette'}],
#         u'word': u'into'}],
#       u'word': u'tricking'}],
#     u'word': u'by'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'kills'},
#  {u'NE': u'',
#   u'POS_coarse': u'VERB',
#   u'POS_fine': u'VBZ',
#   u'arc': u'ROOT',
#   u'lemma': u'kill',
#   u'modifiers': [{u'NE': u'',
#     u'POS_coarse': u'PRON',
#     u'POS_fine': u'PRP',
#     u'arc': u'nsubj',
#     u'lemma': u'-PRON-',
#     u'modifiers': [],
#     u'word': u'He'},
#    {u'NE': u'GPE',
#     u'POS_coarse': u'PROPN',
#     u'POS_fine': u'NNP',
#     u'arc': u'dobj',
#     u'lemma': u'Fulwa',
#     u'modifiers': [],
#     u'word': u'Fulwa'},
#    {u'NE': u'',
#     u'POS_coarse': u'ADV',
#     u'POS_fine': u'RB',
#     u'arc': u'advmod',
#     u'lemma': u'well',
#     u'modifiers': [{u'NE': u'',
#       u'POS_coarse': u'ADV',
#       u'POS_fine': u'RB',
#       u'arc': u'advmod',
#       u'lemma': u'as',
#       u'modifiers': [],
#       u'word': u'as'},
#      {u'NE': u'',
#       u'POS_coarse': u'ADP',
#       u'POS_fine': u'IN',
#       u'arc': u'prep',
#       u'lemma': u'for',
#       u'modifiers': [{u'NE': u'',
#         u'POS_coarse': u'NOUN',
#         u'POS_fine': u'NN',
#         u'arc': u'pobj',
#         u'lemma': u'betrayal',
#         u'modifiers': [{u'NE': u'',
#           u'POS_coarse': u'ADJ',
#           u'POS_fine': u'PRP$',
#           u'arc': u'poss',
#           u'lemma': u'-PRON-',
#           u'modifiers': [],
#           u'word': u'her'}],
#         u'word': u'betrayal'}],
#       u'word': u'for'}],
#     u'word': u'well'},
#    {u'NE': u'',
#     u'POS_coarse': u'PUNCT',
#     u'POS_fine': u'.',
#     u'arc': u'punct',
#     u'lemma': u'.',
#     u'modifiers': [],
#     u'word': u'.'}],
#   u'word': u'kills'}]
